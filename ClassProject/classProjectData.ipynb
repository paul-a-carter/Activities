# %%
import pandas as pd
import numpy as np

df = pd.read_csv("h08.csv",header=[0,1])

print(df)

df.to_csv("h08(2).csv",index=True)
# Out:
#                  State          2021 Unnamed: 2_level_0     2020 (41)  \
#     Unnamed: 0_level_1 Median income     Standard error Median income
# 0        United States        70,784                368        68,010
# 1              Alabama        56,929              2,294        54,689
# 2               Alaska        81,133              3,967        74,746
# 3              Arizona        70,821              3,394        67,088
# 4             Arkansas        50,784              1,440        50,777
# ..                 ...           ...                ...           ...
# 102           Virginia        80,268              2,953        86,053
# 103         Washington        87,648              3,307        85,157
# 104      West Virginia        46,836              2,247        54,396
# 105          Wisconsin        69,943              3,133        70,553
# 106            Wyoming        71,052              3,919        68,506
#
# ...
