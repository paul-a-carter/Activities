# %% [markdown]
# ## Matplotlib: Visualization with Python
#
# OBJECTIVES:
# - What is Matplotlib
# - Learn the steps in graph creation
# - review various types of graphs

# %% [markdown]
# ## What is Matplotlib
# - **Matplotlib** - Python library for creating static, animated and interactive visualizations
#     - Creates plots
#     - Creates interactive figures that can zoom, pan and update
#     - Customize styles and layouts
#     - Export results
# - **NOTE**: In curriculum are additional links on using Matplotlib

# %% [markdown]
# ### NOTES
# >
# > ## What is Matplotlib
# >
# > Matplotlib is a comprehensive library for creating static, animated, and interactive visualizations in Python.
# >
# >         Matplotlib makes easy things easy and hard things possible.
# >
# > - Create publication quality plots.
# > - Make interactive figures that can zoom, pan, update.
# > - Customize [visual style](https://matplotlib.org/stable/gallery/style_sheets/style_sheets_reference.html) and customize [layout](https://matplotlib.org/stable/tutorials/provisional/mosaic.html).
# > - Export results to many [different file formats](https://matplotlib.org/stable/api/figure_api.html#matplotlib.figure.Figure.savefig).
# > - Embed Matplotlib in [JupyterLab and Graphical User Interfaces](https://matplotlib.org/stable/gallery/#embedding-matplotlib-in-graphical-user-interfaces).
# > - Use a rich array of [third-party packages](https://matplotlib.org/mpl-third-party/) built on Matplotlib.

# %% [markdown]
# # Visualization with Matplotlib Process
# 1. load the necessary packages
# 2. prepare your data
# 3. choose your graph type
# 5. tweak your graph
# 6. organize and label
# 7. save/render graph for output

# %% [markdown]
# # Types of graphs
# - Line graphs
# - Bar Charts & Histograms
# - Pie Charts
# - Scatter plots
# - Box and Whisker Plots

# %% [markdown]
# ## Line Graphs
# - generally used to track changes over time. The time periods can be short or long. You can also track more than one group over the same periods of time.
#
# <img src='./images/line_chart.png'/>

# %% [markdown]
# You will use a line chart when you want to emphasize changes in values for one variable (plotted on the vertical axis) for continuous values of a second variable (plotted on the horizontal). This emphasis on patterns of change is sold by line segments moving consistently from left to right and observing the slopes of the lines moving up or down.
#
# On the horizontal axis, you need a variable that depicts continuous values that have a regular interval of measurement. Very commonly, this variable is a temporal one, generating an observation every minute, hour, day, week, or month. The choice of interval size, or bin, is a decision that the analyst will usually need to make for the data, rather than it being an inherent data characteristic.
#
# On the vertical axis, you will report the value of a second numeric variable for points that fall in each of the intervals defined by the horizontal-axis variable. Often, this will be a statistical summary like a total or average value across events within each bin.
#
# Multiple lines can also be plotted in a single line chart to compare the trend between series. A common use case for this is to observe the breakdown of the data across different subgroups. The ability to plot multiple lines also provides the line chart a special use case where it might not usually be selected. Normally, we would use a histogram to depict the frequency distribution of a single numeric variable. However, since it’s tricky to plot two histograms on the same set of axes, the line chart serves as a good mode of comparison as a substitute. Line charts used to depict frequency distributions are often called frequency polygons.

# %% [markdown]
# # Class Example

# %%
# place code for class example here

# %%
import pandas as pd
import matplotlib.pyplot as plt 
import numpy as np 

x = [0,1,2,3,4]
y = [0,2,4,6,8]


#resize your graph 
# plt.figure(figsize=(5,3),dpi=300)

## Add the first line 

#keyword argument notation
plt.plot(x,y, label = '2x', color = 'red', linewidth = 2, linestyle = '-', marker = '^', markersize=12)

#shorthand notation
#shorthand_format = '[color][marker][line]'
# plt.plot(x,y,'b^--', label = '2x')

##Add the second line to your graph

# define new interval to graph 
x2 = np.arange(0,5,0.5)
print(len(x2),x2)

#[0.  0.5 1.  1.5 2.  2.5 3.  3.5 4.  4.5]
# Plot 1st part of the line 
plt.plot(x2[:6],x2[:6]**2, 'r', label = 'x^2')
# Plot the remainder of the line
plt.plot(x2[5:],x2[5:]**2,'g--')

#print(x2[:6]**2,x2[5:]**2)

#Add a graph title and update default font using fontdict parameter
plt.title('Our first Graph!', fontdict={'fontname':'Comic Sans MS', 'fontsize':20})

#Add x and y axis labels 
plt.xlabel('x label',fontdict={'fontname':'Comic Sans MS'} )
plt.ylabel('y label',fontdict={'fontname':'Comic Sans MS'})

# X and Y tick labels
plt.xticks([0,1,2,3,4,5])
# plt.yticks([0,1,2,3,4,5,6,7,8])

#add graph legend 
plt.legend()

# save your graph as a png (dpi of 300 will make sure the resolution of the graph is good for printing)
plt.savefig('mygraph.png',dpi=300)

#show plot
plt.show()
# Out:
# 10 [0.  0.5 1.  1.5 2.  2.5 3.  3.5 4.  4.5]

# %% [markdown]
# # Example: Gas Prices over time

# %%
# place code for class example here

# %%
# import gas price data from csv into data frame 
gas = pd.read_csv('gas_prices.csv')
print(gas)
# Set fig size 

plt.figure(figsize=(8,5))


#Add a title to the Plot 
plt.title('Gas Prices over Time in USD', fontdict={'fontweight': 'bold', 'fontsize':14})

# choose which countries (USA, Canada, UK) to plot 
plt.plot(gas.Year, gas.USA, 'r.-', label = 'USA')
plt.plot(gas.Year,gas.Canada, 'b.-',label = 'Canada')
plt.plot(gas.Year,gas.UK, 'g.-', label = 'UK')



# Another Way to plot many values!
# countries_to_look_at = ['Australia', 'USA', 'Canada', 'South Korea']
# for country in gas:
#     if country in countries_to_look_at:
#         plt.plot(gas.Year, gas[country], marker='.')


#change the tick numbers on X axis 
plt.xticks(gas.Year[::3])

#add X and Y labels 
plt.ylabel('Price per Gallon (USD)')
plt.xlabel('Country')

# add a legend 
plt.legend()

#Save your graph 
plt.savefig('GasPlot.png', dpi=300)
# Out:
#     Year  Australia  Canada  France  Germany  Italy  Japan  Mexico  \
# 0   1990        NaN    1.87    3.63     2.65   4.59   3.16    1.00
# 1   1991       1.96    1.92    3.45     2.90   4.50   3.46    1.30
# 2   1992       1.89    1.73    3.56     3.27   4.53   3.58    1.50
# 3   1993       1.73    1.57    3.41     3.07   3.68   4.16    1.56
# 4   1994       1.84    1.45    3.59     3.52   3.70   4.36    1.48
# 5   1995       1.95    1.53    4.26     3.96   4.00   4.43    1.11
# 6   1996       2.12    1.61    4.41     3.94   4.39   3.64    1.25
# 7   1997       2.05    1.62    4.00     3.53   4.07   3.26    1.47
# 8   1998       1.63    1.38    3.87     3.34   3.84   2.82    1.49
# 9   1999       1.72    1.52    3.85     3.42   3.87   3.27    1.79
# 10  2000       1.94    1.86    3.80     3.45   3.77   3.65    2.01
# 11  2001       1.71    1.72    3.51     3.40   3.57   3.27    2.20
# 12  2002       1.76    1.69    3.62     3.67   3.74   3.15    2.24
# ...

# %% [markdown]
# ## Breakout 1

# %% [markdown]
# ## Bar Charts
#
# - Bar chart: works well to compare data across categories, or categorical data
# - Histogram : mainly for numeric data, helps to understand underlying distribution of the data (shape or skewness)

# %% [markdown]
# <img src="./images/hist_vs_bar.jpeg"/>

# %% [markdown]
# ## Bar Charts Example

# %%
# code goes here 
import pandas as pd
import matplotlib.pyplot as plt

# %%
#prepare data 
labels = ['A', 'B', 'C']
values = [1,4,2]

#change graph size
plt.figure(figsize=(5,3), dpi=100)

#render set-up (discuss barh)
bars = plt.bar(labels, values)

#tweak --> place patters on bars 
patterns = ['/', 'O', '*']
for bar in bars:
    bar.set_hatch(patterns.pop(0))


#save figure
plt.savefig('barchart.png', dpi=300)

#render graph 
plt.show()

# %%
# place code here

# %%
# prepare data 
df = pd.read_csv('./resources/matplotlib_data/use_titanic.csv')
df

x = df['Passenger Class']
y = df['Survived']
ticks =[1,2,3,4]

#prepare to render 
bar = plt.hist(x,bins=ticks, color='Green', density=True)
plt.xticks(ticks)

    
#render

plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 2
#       1 # prepare data
# ----> 2 df = pd.read_csv('./resources/matplotlib_data/use_titanic.csv')
#       3 df
#       5 x = df['Passenger Class']
#
# ...

# %%
# place code here

# %%
# Data
import numpy as np

groups = np.array(['G1', 'G2', 'G3', 'G4', 'G5'])
values1 = np.array([12, 19, 14, 27, 16])
values2 = np.array([21, 30, 15, 17, 20])
values3 = np.array([5,3,6,10,7])

# Stacked bar chart
plt.bar(groups, values1)
plt.bar(groups, values2, bottom = values1)
plt.bar(groups, values3, bottom = np.add(values1,values2))


#render
plt.show()

# %% [markdown]
# # Scatter Plot
# - A scatter plot (aka scatter chart, scatter graph) uses dots to represent values for two different numeric variables.

# %% [markdown]
# ### When to use a scatter plot?
# - Use a scatter plot to observe and show relationships between two numeric variables.
# - Use a scatter plot when you have two variables that pair well together.
#
# ### When not to use a scatter plot?
# - when your data is not related
# - when you have a very large amount of data
#
# ### Keep in mind
# - correlation is not causation

# %% [markdown]
# <img src = './images/scatter_corre.png'/>

# %% [markdown]
# # Scatter Plot Example

# %%
# place code here

# %%
import pandas as pd
import matplotlib.pyplot as plt 
import numpy as np 

df = pd.read_csv('./resources/matplotlib_data/insurance.csv')

x = df['bmi']
y = df['charges']
e = df['smoker'].replace({'no':0,'yes':1})

#render plot and the add hue change  for smokers c=df['smoker'],cmap= 'jet'
plt.scatter(x,y)

##tweak
# add a trendline
z = np.polyfit(x, y, 1)
p = np.poly1d(z)
plt.plot(x,p(x),'r')

# add labels
plt.xlabel('BMI')
plt.ylabel('Charges')

# add title 
plt.title('Examining the relationship between BMI and insurance charges')

# show graph 
plt.show()

# %% [markdown]
# # Breakout 2
# - jump into breakout rooms and complete section 2 in the breakout notebook

# %% [markdown]
# # Pie Chart
# - A pie chart helps organize and show data as a percentage of a whole.
#
# <img src = './images/piechart.png'/>

# %% [markdown]
# Pie charts have a fairly narrow use-case that is encapsulated particularly well by its definition. In order to use a pie chart, you must have some kind of whole amount that is divided into a number of distinct parts. Your primary objective in a pie chart should be to compare each group’s contribution to the whole, as opposed to comparing groups to each other. If the above points are not satisfied, the pie chart is not appropriate, and a different plot type should be used instead.
#
# The values that comprise a whole and the categories that divide the whole generally come in two major varieties. First of all, is when the ‘whole’ represents a total count. Examples of this include votes in an election divided by candidate, or number of transactions divided by user type (e.g. guest, new user, existing user).
#
# A second type of ‘whole’ is when the total is a sum over an actual data variable. For example, we might be interested not in the number of transactions, but the monetary total from all transactions. Dividing this total by an attribute like user type, age bracket, or location might provide insights as to where the business is most successful.

# %% [markdown]
# # Pie Chart Example

# %%
#load necessary packages 
import matplotlib.pyplot as plt 
import pandas as pd 
import numpy as np 

# class example code goes here

# %%
# prepare data & labels
df = pd.read_csv('./resources/matplotlib_data/Electric_Vehicle_Population_Data 2.csv')

x = df['Model'].value_counts().head(10)
labels = x.index.values.tolist()

# render the data 

plt.pie(x, labels=labels,autopct='%1.1f%%')

# tweak
plt.figure(figsize=(8,6), dpi=300)

#save
plt.savefig('pie_example.png')

#render
plt.show()

# %%
#Class example goes here

# %%
# prepare data & labels
df = pd.read_csv('./resources/matplotlib_data/Electric_Vehicle_Population_Data 2.csv')

x1 = df['Model'].value_counts().head(5)
l1 = x1.index.values.tolist()

x2 = df['Electric Vehicle Type'].value_counts().head()
l2 = x2.index.values.tolist()

# render the data 
fig, (ax1,ax2) = plt.subplots(1,2)
ax1.pie(x1, labels=l1, autopct='%1.1f%%')
ax2.pie(x2,labels=['BEV','PHEV'], autopct='%1.1f%%', startangle=90)

# tweak if needed 
ax2.set_aspect(1)

#save
fig.savefig('test.png')

#render
plt.show()

# %% [markdown]
# # Breakout 3

# %% [markdown]
# # Subplots
#
# When we called pylab.plot previously, there were a few things happening in the background:
#
# - matplotlib creates a Figure instance, which is an object describing the plot window and its properties, and containing lists of all its elements
# - matplotlib createa an Axes element within the figure. An axes can be thought of as a plotting window, where data can be arranged by x and y coordinates.
#
# ```python
#
# fig, ax = plt.subplots()
#
# ```

# %%
#example using plt.subplots()
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt 

#prepare data 
g = np.array(['G1', 'G2', 'G3', 'G4', 'G5'])
v1 = np.array([12, 19, 14, 27, 16])
v2 = np.array([21, 30, 15, 17, 20])
v3 = np.array([5,3,6,10,7])

# initialize plot objects 
fig, ax = plt.subplots()

# create bar graphs 
ax.bar(g,v1, label = 'Yes')
ax.bar(g,v2, bottom= v1, label= 'No')
ax.bar(g,v3, bottom=np.add(v1,v2), label= 'Maybe')

##tweak
#add labels 
ax.set_xlabel('x axis')
ax.set_ylabel('y axis')

#add title
ax.set_title('Stacked Bar Graph', fontdict={'fontweight':'bold', 'horizontalalignment':'center'})

#add a legend 
fig.legend()

#save graph 
fig.savefig('stackedbar.png')

# %%
# place code here for next subplot example

# %%
#prepare data 
g = np.array(['G1', 'G2', 'G3', 'G4', 'G5'])
v1 = np.array([12, 19, 14, 27, 16])
v2 = np.array([21, 30, 15, 17, 20])
v3 = np.array([5,3,6,10,7])
v4 = np.array([5,3,6,10,7])
w = 0.75


## initialize plot objects 

#1 row, 3 columns 
# fig, (ax1,ax2,ax3) = plt.subplots(1,3, figsize=(12,4))

# 2 columns, 2 rows 
fig, ((ax1,ax2),(ax3,ax4)) = plt.subplots(2,2, figsize=(8,6))

# call bar objects 
ax1.bar(g,v1, color='b')
ax2.bar(g,v2, color= 'orange')
ax3.bar(g,v3, color='green')
ax4.bar(g,v4,color='red')



#render
plt.show()
